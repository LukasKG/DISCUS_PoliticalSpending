# %%
# download and install tesseract from here: https://github.com/UB-Mannheim/tesseract/wiki
# install poppler : https://anaconda.org/conda-forge/poppler 
    # in anaconda prompt: conda install -c conda-forge poppler

# %%
from pdf2image import convert_from_path

from PIL import Image
from pytesseract import pytesseract

import pandas as pd

import os

# %% [markdown]
# # code for a single pdf below

# %%
# # pdf to an image

# pdfs = r"invoices/pdf_trial2.pdf"
# pages = convert_from_path(pdfs, 350)

# i = 1
# for page in pages:
#     image_name = "Page_" + str(i) + ".jpg"  
#     page.save(image_name, "JPEG")
#     i = i+1

# %%
# # Defining paths to tesseract.exe
# # and the image we would be using
# path_to_tesseract = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
# image_path = r"Page_1.jpg"

# # Opening the image & storing it in an image object
# img = Image.open(image_path)

# # Providing the tesseract executable
# # location to pytesseract library
# pytesseract.tesseract_cmd = path_to_tesseract

# # Passing the image object to image_to_string() function
# # This function will extract the text from the image
# text = pytesseract.image_to_string(img)

# # Displaying the extracted text
# print(text[:-1])
# Out:
# e Brexit Party Organisaticn
#
# Date Item
# 7-Nov-19 Manor House Single Bed & Breakfast
# 7-Nov-19 Manor House Double Bed & Breakfast
# 8-Nov-19 Manor House Single Bed & Breakfast
# 8-Nov-19 Manor House Double Bed & Breakfast
# Deposit Due at 100%
#
# Proforma Number [i
#
# Page 1
#
# Date +Nov-i9
#
# Gross Rate Numbers
#
# £97.00 3
# £127.00 9
# £97.00 4
# £127.00 9
#
# Total
# £291.00
# £1,143.00
# £388.00
# £1,143.00
#
# £2,965.00
#
# To enable us to process your deposit payment efficiently, please quote the above
# pro forma reference number on all payments made to The Celtic Manor Resort
#
# surcharge bein Be n rd
# Please note This is Not a VAT Invoice
#
# To enabie you to pay us BACS we nave liste
#
# Cee

# %%
data_full = pd.read_csv('spending_2019.csv')
data = data_full.iloc[:,[0,1,3,4,5,7, 15]]

# %%
data['invoice_id'] = data['RedactedSupportingInvoiceId'] 
data.pop('RedactedSupportingInvoiceId')
# Out:
# <ipython-input-81-24d4e5e181fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['invoice_id'] = data['RedactedSupportingInvoiceId']
# 0        66836.0
# 1        65844.0
# 2        66755.0
# 3        68767.0
# 4        65153.0
#           ...
# 22715        NaN
# 22716        NaN
# 22717        NaN
# 22718        NaN
# 22719        NaN
# Name: RedactedSupportingInvoiceId, Length: 22720, dtype: float64

# %% [markdown]
# # code for all pdfs and images in a given folder
#
# - see paths below
# - check paths and directories

# %%
 # change invoices_trial to invoices
invoice_directory = 'C:/Users/Helena/DISCUS_polspending/DISCUS_Hack_PoliticalSpending/invoices' 

# print("Files and directories in a specified path:")

for filename in os.listdir(invoice_directory):
    f = os.path.join(invoice_directory,filename)
    if os.path.isfile(f):
        # print(f)
        
        pdfs = f
        pages = convert_from_path(pdfs, 350)
        
        i = 1
        invoice_id = f[-9:-4]
        # print('invoice no.' + invoice_id + 'converted and saved')
        
        for page in pages:
            image_name = invoice_id +"_Page_" + str(i) + ".jpg"  
            page.save('images/'+ image_name, "JPEG")
            i = i+1 

print('finished')
# Out:
# C:\Users\Helena\anaconda3\lib\site-packages\PIL\Image.py:2847: DecompressionBombWarning: Image size (169884400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# C:\Users\Helena\anaconda3\lib\site-packages\PIL\Image.py:2847: DecompressionBombWarning: Image size (140554992 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# ---------------------------------------------------------------------------
# DecompressionBombError                    Traceback (most recent call last)
# <ipython-input-83-f9a892730b11> in <module>
#      10
#      11        pdfs = f
# ---> 12        pages = convert_from_path(pdfs, 350)
#      13
#      14        i = 1
#
# ~\anaconda3\lib\site-packages\pdf2image\pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
#     220             )
#     221         else:
# --> 222             images += parse_buffer_func(data)
#     223
#     224     if auto_temp_dir:
#
# ~\anaconda3\lib\site-packages\pdf2image\parsers.py in parse_buffer_to_ppm(data)
#      19         size_x, size_y = tuple(size.split(b" "))
#      20         file_size = len(code) + len(size) + len(rgb) + 3 + int(size_x) * int(size_y) * 3
# ---> 21         images.append(Image.open(BytesIO(data[index : index + file_size])))
#      22         index += file_size
#      23
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2942         return None
#    2943
# -> 2944     im = _open_core(fp, filename, prefix, formats)
#    2945
#    2946     if im is None:
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in _open_core(fp, filename, prefix, formats)
#    2929                     fp.seek(0)
#    2930                     im = factory(fp, filename)
# -> 2931                     _decompression_bomb_check(im.size)
#    2932                     return im
#    2933             except (SyntaxError, IndexError, TypeError, struct.error):
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in _decompression_bomb_check(size)
#    2839
#    2840     if pixels > 2 * MAX_IMAGE_PIXELS:
# -> 2841         raise DecompressionBombError(
#    2842             f"Image size ({pixels} pixels) exceeds limit of {2 * MAX_IMAGE_PIXELS} "
#    2843             "pixels, could be decompression bomb DOS attack."
#
# DecompressionBombError: Image size (288120000 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.

# %%
 # extracting text from images
    
images_directory = 'C:/Users/Helena/DISCUS_polspending/DISCUS_Hack_PoliticalSpending/images' 
path_to_tesseract = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

dict_invoices = {'invoice_id':[] , 'text':[] }

# print("Files and directories in a specified path:")

for filename in os.listdir(images_directory):
    
    f = os.path.join(images_directory,filename)
    if os.path.isfile(f):
       # print(f)
        
        image_path = f
        
        img = Image.open(image_path)
        pytesseract.tesseract_cmd = path_to_tesseract
        
        invoice_no = image_path[-16:-11] 
        
        text = pytesseract.image_to_string(img)
        
        # text needs to be appended to a dictionary: key = invoice_id, all pages are text
        
        dict_invoices["invoice_id"].append(invoice_no)
        dict_invoices["text"].append(text)
        
        
        
        
#         print('invoice_no.:'+ invoice_no + '\n********************\n'+text +'\n\n')


print('finished')
# Out:
# invoice_no.:62311
# ********************
# SRIPT
#
# Sth February 2020
#
# Fantage, postproduction for video for Aontu
#
# Film, Post Production, video :
#
# Total:
#
#
#
#
# invoice_no.:62312
# ********************
# PBD
#
# INVOICE
#
# Alliance HQ, lewelce Date Pale blue Dot Creative
# 88 University Street 18 Now 2009 34-36 Bedlord Street
# Belfast Gelfast
# a lewolce Nuenber 812 7FF
# BT? LHE
# VAT Nuewer
# Description Quantity Unit Price vaT Amount Ga?
#
# Delivery of new 2 min 40 PEB to include
#
# edit, studio fees, sound mix & clocks,
#
# music licance, dispatch to stations, 1.00 3,300.00 20% 3,300.00
# cameraman & backdrop, subtitles and
#
# purchase of stock footage
#
# Radio est (Ke Boom) 1.00 5.00 20% 75.00
# ; TIARA Subtona = 3,375.00
# Total VAT 20% 675.00
#
# invoice Total Gar 4,050 ow
#
# Total Net Payrnents GF 0.00
#
# Amount Due GBP 4,059.00
#
# Nine Nate: 18 Mer 2019
#
# au eee ee eee eee ee ee ee eee ee eee eee eee eee ee
#
# PAYMENT ADVICE Cotamer ARene HQ
# tevelce Number a
# To: Pale Give Dot Creative
# 34-36 Bedford Street Amount Due 4,050.00
# belfast Ouse Date 18 Gee 2019
# BT2 TFF
#
# - pe
#
# Corrgany Regtrivetion Mic NOADEEDS Megitieved Office: 4 16 Gechord Sarent, Bethe aT? 77e
#
#
#
# invoice_no.:62313
# ********************
# Alexander Boyd Displays Ltd
# Lambeg Mis
#
# Ballyekeegh Road
#
# Lambeg
# Lisburn
# County Anirien
# Br27 55x
#
# Alexander Boyd Displays
#
# INVOICE TO: _— - :
# “The Aliancn Party }
# BS University Street :
# Belfast DATE ctl
# BT7 1HE ORDER NUMBER
#
# “ORDERED BY
#
# vaT ves
#
# SSAVICE DETALS NET AMOUNT VAT AMOUNT
#
# 33) rex Panels
#
# 2. “v48" x 4mm - 4 Types
# Full Colour 1 Side
#
# Cable Tles
#
# Paula Gradshaw x 120
# Coin Terryson x 70
#
# Sorcha Eastwood x 70
# John Bla x 70
#
# @ £1,115.00
#
# 550 Correx Panels
#
# 32° x 48" x 4mm - 3 Types
#
# Full Colour 3 Side
#
# Cable Ties
#
# Demand Better x 194
#
# You Can Demand Better x 193 »)
#
# Had 2500. 193
# - Fas ty pode
#
# Las
# fort rex Panels
# 24 24" x 4mm
# Full Colour 1 Sicke
#
# Cable Ties
# Vobe Bradshaw
# @ £1,000.00
# "GENERAL ELECTION 2019* 4,910.00 982.00
# SS i . -
# [TOTAL NETAMOUNT| £ 4,910.00 |
# Delivered 6th November 2019 [TOTAL VATAMOUNT)  £ $62.00 |
# INVOICE TOTAL £ 5,692.00 |
# Docket No- | :
#
# TERMS - STRICTLY MET SODAYS:
# OWNERSHIP 1 NOT TRANSFERRED UNTIL GO00S ARG PAD FOR On FUEL
#
# SY WAYSTOPAY
#
#
#
#
# invoice_no.:62314
# ********************
# fa £ayes-co 7128 Ueq Wo BS
#
# pave 2B Jia aire
#
# , (iepScE Peery i
# _ ge UsVNeteir7y ST Bers ee
#
# Pores eters + come
#
# }
# Sostt MetENST IS | |
# emer weenst S36 | ||
# Noort pee sso | ||
# _perasT corte |
# b Retceer+cezor So! ||
#
# E pete] So
# GE nesttey oe oe
#
# Ss Aetreet 160
# PEELS TROIS so
#
# remem lo&) | |
# igo) fF £9257]
#
# iqso SB $ise a
#
# COME TIES re srrUED SO || —
# ysep ss Seo|—S|| |
# S 6fc! ||

# %%
# creating a dataframe  

invoice_info_df = pd.DataFrame(data = dict_invoices)

# change invoice_id type from string to numeric - necessary for merging later

invoice_info_df['invoice_id'] = invoice_info_df['invoice_id'].apply(pd.to_numeric)

invoice_info_df.head()
# Out:
#    invoice_id                                               text
# 0       62311  SRIPT\n\nSth February 2020\n\nFantage, postpro...
# 1       62312  PBD\n\nINVOICE\n\nAlliance HQ, lewelce Date Pa...
# 2       62313  Alexander Boyd Displays Ltd\nLambeg Mis\n\nBal...
# 3       62314  fa £ayes-co 7128 Ueq Wo BS\n\npave 2B Jia aire...

# %%
# merge data and invoice_data on invoice_id variable

data_final = data.merge(invoice_info_df, left_on='invoice_id', right_on ='invoice_id')

data_final.head()

data_final.to_csv('data_incl_ExtractedText.csv')
# Out:
#        ECRef                            RegulatedEntityName  \
# 0  SP0496197  Alliance - Alliance Party of Northern Ireland
# 1  SP0496195  Alliance - Alliance Party of Northern Ireland
# 2  SP0496196  Alliance - Alliance Party of Northern Ireland
# 3  SP0495572                                          Aontú
#
#   RegulatedEntityType TotalExpenditure DateIncurred  \
# 0     Political Party        £7,485.00   12/12/2019
# 1     Political Party        £4,050.00   18/11/2019
# 2     Political Party        £2,755.00   06/11/2019
# 3     Political Party          £517.88   29/11/2019
#
#                   SupplierName  invoice_id  \
# 0                  Gordon Duff     62314.0
# 1                Pale Blue Dot     62312.0
# 2  Alexander Boyd Displays Ltd     62313.0
# 3                  Gript Media     62311.0
#
#                                                 text
# 0  fa £ayes-co 7128 Ueq Wo BS\n\npave 2B Jia aire...
# 1  PBD\n\nINVOICE\n\nAlliance HQ, lewelce Date Pa...
# 2  Alexander Boyd Displays Ltd\nLambeg Mis\n\nBal...
# 3  SRIPT\n\nSth February 2020\n\nFantage, postpro...
