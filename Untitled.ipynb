# %%
import pandas as pd

# %%
data_nonT = pd.read_csv('coding_notransport.csv')
data_T = pd.read_csv('coding_transport.csv')

# %%
data_T.head()
# Out:
#       Unnamed: 0         Unnamed: 1   Unnamed: 2        Unnamed: 3  \
# 0      Supplier               Party  Total Spend  Expense Category
# 1       Abi Bell  Liberal Democrats    £1,936.07         Transport
# 2  Abigail Baker  Liberal Democrats      £748.80         Transport
# 3    Adam Prices        Plaid Cymru      £275.85         Transport
# 4  Adam Williams  Liberal Democrats      £484.06         Transport
#
#       Unnamed: 4 Unnamed: 5         Unnamed: 6  Unnamed: 7  Transport  \
# 0      Supplier       Notes  Missing invoices?         NaN  Transport
# 1       Abi Bell        NaN                  Y  Under £200        NaN
# 2  Abigail Baker        NaN                NaN         NaN        NaN
# 3    Adam Prices        NaN                  Y  Under £200        NaN
# 4  Adam Williams        NaN                 Y   Under £200        NaN
#
#    Unnamed: 9  ... Unnamed: 111           Unnamed: 112 Unnamed: 113  \
# 0         NaN  ...          NaN  Ordinance survey data          NaN
# ...

# %%
data_nonT.head()
# Out:
#                       Unnamed: 0                        Unnamed: 1  \
# 0                       Supplier                             Party
# 1                   Facebook Ltd  Plaid Cymru - The Party of Wales
# 2                       Facebook             Scottish Family Party
# 3  Reach Publishing Services LTd  Plaid Cymru - The Party of Wales
# 4              EColour Print Ltd           Social Democratic Party
#
#     Unnamed: 2        Unnamed: 3                     Unnamed: 4  \
# 0  Total Spend  Expense Category                       Supplier
# 1   £25,292.37       Advertising                   Facebook Ltd
# 2    £2,368.68       Advertising                       Facebook
# 3   £21,600.00       Advertising  Reach Publishing Services LTd
# 4    £2,078.00       Advertising              EColour Print Ltd
#
#             Unnamed: 5  ADVERTISING AND PRESS   Unnamed: 7  \
# 0  More than 1 service  ADVERTISING AND PRESS  Merchandise
# ...

# %%
# combine datasets including supplier,party, total and expense category

data1 = data_nonT.iloc[0:,:4]
data2 = data_T.iloc[0:,:4]
# Out:
#       Unnamed: 0         Unnamed: 1   Unnamed: 2        Unnamed: 3
# 0      Supplier               Party  Total Spend  Expense Category
# 1       Abi Bell  Liberal Democrats    £1,936.07         Transport
# 2  Abigail Baker  Liberal Democrats      £748.80         Transport
# 3    Adam Prices        Plaid Cymru      £275.85         Transport
# 4  Adam Williams  Liberal Democrats      £484.06         Transport

# %%
data1.head()
# Out:
#                                0                                 1  \
# 1                       Supplier                             Party
# 2                   Facebook Ltd  Plaid Cymru - The Party of Wales
# 3                       Facebook             Scottish Family Party
# 4  Reach Publishing Services LTd  Plaid Cymru - The Party of Wales
# 5              EColour Print Ltd           Social Democratic Party
#
#              2                 3
# 1  Total Spend  Expense Category
# 2   £25,292.37       Advertising
# 3    £2,368.68       Advertising
# 4   £21,600.00       Advertising
# 5    £2,078.00       Advertising

# %%
data2.head()
# Out:
#       Unnamed: 0         Unnamed: 1   Unnamed: 2        Unnamed: 3
# 0      Supplier               Party  Total Spend  Expense Category
# 1       Abi Bell  Liberal Democrats    £1,936.07         Transport
# 2  Abigail Baker  Liberal Democrats      £748.80         Transport
# 3    Adam Prices        Plaid Cymru      £275.85         Transport
# 4  Adam Williams  Liberal Democrats      £484.06         Transport

# %%
# data_comb = pd.concat([data1, data2], axis = 1)
# data_comb.head()
